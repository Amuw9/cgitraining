# %% [markdown]
# <a href="https://colab.research.google.com/github/Amuw9/cgitraining/blob/main/test_connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.getenv('OPENAI_API_KEY'):
  print("Valid OpenAI API key.")
else:
  print("Invalid or missing OpenAI API key. Please add ur key to Colab secrets as 'OPENAI_API_KEY'.")
# Out:
# Invalid or missing OpenAI API key. Please add ur key to Colab secrets as 'OPENAI_API_KEY'.
