# %% [markdown]
# <a href="https://colab.research.google.com/github/Amuw9/cgitraining/blob/main/DAY10_AAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **use case :- car has problem**
#
# **chaining :-**
#
# First check the error code → then identify the problem → then decide whether the car can be driven.
# step by step check
#
# **Routing:**-
#
# Routing = Decide which path/person/service should handle the problem.
# where to go
# Flat tire → Tire shop
# Engine problem → Engine mechanic
# Brake problem → Brake specialist
#
#  Orchestration = Coordinator manages workers
# car service center :-where it check all break tier engine
# Orchestration = One coordinator manages multiple specialists/workers.
#
# **Evaluator**
#
# Evaluator-Optimizer = Check and improve
#
# The engine needs replacement
# After the process
# The evaluator might find:
# The engine doesn't need replacement. The problem is only a faulty sensor
#
# The diagnosis is improved based on evaluation.
# Evaluator-Optimizer = Check the answer → find problems → improve it → check again.
#
#  HITL(Human in the Loop): **bold text**
#
# Suppose the diagnostic system is not sure whether the engine is safe to drive.
# HITL = When AI is uncertain or the decision is important, involve a human.
#
# Escalation
#
# Escalation = Move the problem to a higher level
# Suppose the local mechanic cannot identify the problem.
#
# Local mechanic → Senior mechanic → Manufacturer specialist
# Escalation = If the current person/system cannot handle the problem, send it to a higher level.
#
# Parallelization
#
#  Parallelization = Do things at the same time
# Instead of checking everything one by one, the service center can check several things simultaneously
#
# Parallelization = Multiple independent tasks happen at the same time.
