# %% [markdown]
# <a href="https://colab.research.google.com/github/Amuw9/cgitraining/blob/main/OKR_READY_outcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date
import matplotlib
matplotlib.rcParams['figure.dpi'] = 110
print("Environment ready ✅")
# Out:
# Environment ready ✅

# %% [markdown]
# Strategic Intent: Become the fastest, most trusted checkout experience in mid-market e-commerce within 12 months, measured by conversion rate and repeat-purchase rate — not by feature count.
#
# Homework
# Strategic Intent : "Become the most reliable, zero-downtime database platform for high-growth SaaS startups within 12 months, measured by uptime percentage and recovery speed — not by product breadth.
#
# For above strategic intent, draft the 1) OKRs,2) Initiatives, 3) CUJ walkthrough all mock screens, 4) Create a summary roadmap of OKRs and initiatives

# %%
okrs = pd.DataFrame([
    {"objective": "Make checkout the fastest in our category",
     "key_result": "Cut checkout time from 90s to 30s",
     "baseline": 90, "current": 52, "target": 30, "unit": "seconds", "lower_is_better": True,
     "owner": "Checkout squad", "quarter": "Q3"},
    {"objective": "Make checkout the fastest in our category",
     "key_result": "Raise checkout conversion rate",
     "baseline": 61, "current": 71, "target": 80, "unit": "%", "lower_is_better": False,
     "owner": "Checkout squad", "quarter": "Q3"},
    {"objective": "Make checkout the fastest in our category",
     "key_result": "Increase repeat-purchase rate",
     "baseline": 22, "current": 27, "target": 35, "unit": "%", "lower_is_better": False,
     "owner": "Growth squad", "quarter": "Q4"},
    {"objective": "Make checkout the fastest in our category",
     "key_result": "Increase successful checkouts processed per minute from 500 to 1,000",
     "baseline": 50, "current": 80, "target": 100, "unit": "checkouts/min", "lower_is_better": False,
     "owner": "Checkout platform squad", "quarter": "Q3"},
    {"objective": "Make checkout the fastest in our category",
     "key_result": "Reduce checkout abandonment rate from 39% to 20%",
     "baseline": 39, "current": 29, "target": 20, "unit": "%", "lower_is_better": True,
     "owner": "Checkout squad", "quarter": "Q3"},

])

def progress_pct(row):
    span = row.target - row.baseline
    done = row.current - row.baseline
    pct = 0 if span == 0 else (done / span) * 100
    return round(max(0, min(100, pct)), 1)

okrs["progress_pct"] = okrs.apply(progress_pct, axis=1)
okrs
# Out:
#                                    objective  \
# 0  Make checkout the fastest in our category
# 1  Make checkout the fastest in our category
# 2  Make checkout the fastest in our category
# 3  Make checkout the fastest in our category
# 4  Make checkout the fastest in our category
#
#                                           key_result  baseline  current  \
# 0                  Cut checkout time from 90s to 30s        90       52
# 1                     Raise checkout conversion rate        61       71
# 2                      Increase repeat-purchase rate        22       27
# 3  Increase successful checkouts processed per mi...        50       80
# 4   Reduce checkout abandonment rate from 39% to 20%        39       29
#
#    target           unit  lower_is_better                    owner quarter  \
# 0      30        seconds             True           Checkout squad      Q3
# 1      80              %            False           Checkout squad      Q3
# 2      35              %            False             Growth squad      Q4
# 3     100  checkouts/min            False  Checkout platform squad      Q3
# 4      20              %             True           Checkout squad      Q3
#
#    progress_pct
# 0          63.3
# 1          52.6
# 2          38.5
# 3          60.0
# 4          52.6

# %%
fig, ax = plt.subplots(figsize=(9, 4))
y_pos = np.arange(len(okrs))
colors = ["#2C5F2D" if p >= 70 else "#E7B10A" if p >= 40 else "#B85042" for p in okrs.progress_pct]

ax.barh(y_pos, okrs.progress_pct, color=colors, height=0.5)
ax.barh(y_pos, 100, color="#EEEEEE", height=0.5, zorder=0)
ax.barh(y_pos, okrs.progress_pct, color=colors, height=0.5, zorder=1)
ax.set_yticks(y_pos)
ax.set_yticklabels(okrs.key_result)
ax.set_xlim(0, 100)
ax.set_xlabel("Progress toward target (%)")
ax.set_title("Key Result progress — 🟢 on track  🟡 at risk  🔴 behind", fontsize=12, fontweight="bold")
for i, (p, cur, tgt, unit) in enumerate(zip(okrs.progress_pct, okrs.current, okrs.target, okrs.unit)):
    ax.text(102, i, f"{cur}{unit} → target {tgt}{unit}", va="center", fontsize=9)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6261/2159624776.py:15: UserWarning: Glyph 128994 (\N{LARGE GREEN CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6261/2159624776.py:15: UserWarning: Glyph 128993 (\N{LARGE YELLOW CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6261/2159624776.py:15: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.13/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128994 (\N{LARGE GREEN CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.13/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128993 (\N{LARGE YELLOW CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.13/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128308 (\N{LARGE RED CIRCLE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
roadmap = pd.DataFrame([
    {"initiative": "One-click checkout",        "key_result": "Cut checkout time from 90s to 30s",
     "start": "2026-07-01", "end": "2026-08-15", "confidence": "High"},
    {"initiative": "Guest checkout (no signup)", "key_result": "Cut checkout time from 90s to 30s",
     "start": "2026-08-01", "end": "2026-09-15", "confidence": "Medium"},
    {"initiative": "Saved-payment autofill",     "key_result": "Raise checkout conversion rate",
     "start": "2026-07-15", "end": "2026-08-30", "confidence": "High"},
    {"initiative": "Trust badges & reviews",     "key_result": "Raise checkout conversion rate",
     "start": "2026-09-01", "end": "2026-09-30", "confidence": "Medium"},
    {"initiative": "Referral program",           "key_result": "Increase repeat-purchase rate",
     "start": "2026-10-01", "end": "2026-11-15", "confidence": "Low"},
    {"initiative": "Post-purchase loyalty tier",  "key_result": "Increase repeat-purchase rate",
     "start": "2026-11-01", "end": "2026-12-15", "confidence": "Medium"},
    {"initiative": "Checkout infrastructure scaling","key_result": "Increase successful checkouts processed per minute from 50 to 1,00",
     "start": "2026-08-01", "end": "2026-08-31", "confidence": "Medium"},
    {"initiative": "Guest checkout","key_result": "Reduce checkout abandonment rate from 39% to 20%",
     "start": "2026-07-15", "end": "2026-08-15", "confidence": "High"},
    {"initiative": "Simplify checkout form","key_result": "Reduce checkout abandonment rate from 39% to 20%",
     "start": "2026-08-01", "end": "2026-08-31", "confidence": "High"},
])
roadmap["start"] = pd.to_datetime(roadmap["start"])
roadmap["end"] = pd.to_datetime(roadmap["end"])
roadmap["duration_days"] = (roadmap["end"] - roadmap["start"]).dt.days
roadmap
# Out:
#                         initiative  \
# 0               One-click checkout
# 1       Guest checkout (no signup)
# 2           Saved-payment autofill
# 3           Trust badges & reviews
# 4                 Referral program
# 5       Post-purchase loyalty tier
# 6  Checkout infrastructure scaling
# 7                   Guest checkout
# 8           Simplify checkout form
#
#                                           key_result      start        end  \
# 0                  Cut checkout time from 90s to 30s 2026-07-01 2026-08-15
# 1                  Cut checkout time from 90s to 30s 2026-08-01 2026-09-15
# 2                     Raise checkout conversion rate 2026-07-15 2026-08-30
# 3                     Raise checkout conversion rate 2026-09-01 2026-09-30
# 4                      Increase repeat-purchase rate 2026-10-01 2026-11-15
# 5                      Increase repeat-purchase rate 2026-11-01 2026-12-15
# 6  Increase successful checkouts processed per mi... 2026-08-01 2026-08-31
# 7   Reduce checkout abandonment rate from 39% to 20% 2026-07-15 2026-08-15
# 8   Reduce checkout abandonment rate from 39% to 20% 2026-08-01 2026-08-31
#
#   confidence  duration_days
# 0       High             45
# 1     Medium             45
# 2       High             46
# 3     Medium             29
# 4        Low             45
# 5     Medium             44
# 6     Medium             30
# 7       High             31
# 8       High             30

# %%
conf_color = {"High": "#2C5F2D", "Medium": "#E7B10A", "Low": "#B85042"}
krs = roadmap["key_result"].unique()
fig, ax = plt.subplots(figsize=(10, 5))

y = 0
yticks, yticklabels = [], []
for kr in krs:
    rows = roadmap[roadmap["key_result"] == kr]
    for _, r in rows.iterrows():
        ax.barh(y, r.duration_days, left=r.start, height=0.6,
                color=conf_color[r.confidence], edgecolor="white")
        ax.text(r.start, y, f"  {r.initiative}", va="center", ha="left",
                fontsize=8.5, color="white", fontweight="bold")
        yticks.append(y); yticklabels.append("")
        y += 1
    y += 0.6

ax.set_yticks([]); ax.invert_yaxis()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %d"))
ax.set_title("Outcome-based roadmap: initiatives grouped by Key Result", fontsize=13, fontweight="bold")
handles = [plt.Rectangle((0,0),1,1, color=c) for c in conf_color.values()]
ax.legend(handles, conf_color.keys(), title="Confidence", loc="upper right")

# annotate KR group boundaries
running = 0
for kr in krs:
    n = len(roadmap[roadmap["key_result"] == kr])
    ax.axhline(running - 0.3, color="#999999", linewidth=0.6, linestyle="--")
    running += n + 0.6
plt.tight_layout()
plt.show()
