# %% [markdown]
# <a href="https://colab.research.google.com/github/Amuw9/cgitraining/blob/main/DAY09_Assign_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Microservice = a specialized software function exposed as an independent service.
# Agent =An AI agent is different because it can reason about a goal, decide what actions to take, use tools, observe results, and adapt its next action.
# workflow = step by step execution
